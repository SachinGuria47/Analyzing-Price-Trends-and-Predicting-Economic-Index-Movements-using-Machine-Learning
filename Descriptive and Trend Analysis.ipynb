# %% [markdown]
# <a href="https://colab.research.google.com/github/SachinGuria47/Analyzing-Price-Trends-and-Inflation-Patterns-in-India-s-Consumer-Price-Index--Rural-and-Urban--up-t/blob/main/Descriptive%20and%20Trend%20Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # #Analyzing Price Trends and Inflation Patterns in India's Consumer Price Index (Rural and Urban) up to February 2024

# %%
#import Libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# #Load Data

# %%
df = pd.read_csv("cleaned_cpi.csv")
df.info()  #checking the datatypes and value counts in each columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 393 entries, 0 to 392
# Data columns (total 30 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Sector                               393 non-null    object
#  1   Year                                 393 non-null    int64
#  2   Month                                393 non-null    object
#  3   Cereals and products                 393 non-null    float64
#  4   Meat and fish                        393 non-null    float64
#  5   Egg                                  393 non-null    float64
#  6   Milk and products                    393 non-null    float64
#  7   Oils and fats                        393 non-null    float64
#  8   Fruits                               393 non-null    float64
#  9   Vegetables                           393 non-null    float64
#  10  Pulses and products                  393 non-null    float64
# ...

# %% [markdown]
# # Descriptive Analysis 👇
#
#
# *   ## Summary Statistics

# %%
df.describe()
# Out:
#               Year  Cereals and products  Meat and fish         Egg  \
# count   393.000000            393.000000     393.000000  393.000000
# mean   2018.053435            139.733079     160.445038  144.115522
# std       3.252894             18.604015      35.706008   25.265470
# min    2013.000000            107.500000     106.300000  102.700000
# 25%    2015.000000            124.600000     131.300000  123.300000
# 50%    2018.000000            136.800000     146.600000  137.300000
# 75%    2021.000000            148.200000     198.700000  169.200000
# max    2024.000000            188.600000     226.600000  206.100000
#
#        Milk and products  Oils and fats      Fruits  Vegetables  \
# count         393.000000     393.000000  393.000000  393.000000
# mean          143.052926     134.073791  143.211705  159.657761
# std            20.618542      29.927671   19.121444   31.762973
# min           103.600000     101.100000  102.300000  101.400000
# ...

# %% [markdown]
# # Distribution of the numerical features

# %%
num_col = df.select_dtypes(include=np.number).columns.tolist() # to filter out only the columns that contain numerical data types

num_col.remove('Year')
fig,axes = plt.subplots(6,5,figsize=(20,20)) #6 rows and 5 columns
axes = axes.flatten()
for i, col in enumerate(num_col):
    df[col].plot(kind='hist',bins=15, ax=axes[i], edgecolor='black', title=col)
plt.subplots_adjust(hspace=0.5)
plt.show()

# %% [markdown]
# # Boxplot for identifying outliers

# %%
plt.figure(figsize=(15,10))
sns.boxplot(data=df[num_col],orient='h')
plt.xticks(rotation=0)
plt.title('Boxplot for identifying outliers')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %% [markdown]
# # yearly trends visualization

# %%
numeric_columns = df.select_dtypes(include=np.number).drop(columns=['Year'])
yearly_trends = numeric_columns.groupby(df['Year']).mean()
for category in yearly_trends.columns:
    plt.plot(yearly_trends.index, yearly_trends[category], marker='o', linestyle='-', label=category)

plt.xlabel('Year')
plt.ylabel('CPI')
plt.title('Yearly Trends in CPI')
plt.legend(loc='upper right', bbox_to_anchor=(2, 1))
plt.grid(True)
plt.show()

# %% [markdown]
# # correlation analysis

# %%
numeric_columns = df.select_dtypes(include=np.number).drop(columns=['Year'])
correlation = numeric_columns.corr()

# Create a heatmap of the correlation matrix
mask = np.triu(np.ones_like(correlation, dtype=bool))
plt.figure(figsize=(12, 10))
sns.heatmap(correlation, mask=mask,annot=True, cmap='coolwarm', fmt=".2f", annot_kws={"size": 8})
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# ## Removing highly correlated values ranging between > 0.94 and <1

# %%
correl = numeric_columns.corr().abs()

to_drop = set()
for i in range(len(correl.columns)):
    for j in range(i):
        if abs(correl.iloc[i, j]) > 0.94 and abs(correl.iloc[i, j])< 1:
            colname = correl.columns[i]
            to_drop.add(colname)

reduced_data = numeric_columns.drop(columns=to_drop)
reduced_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 393 entries, 0 to 392
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Cereals and products     393 non-null    float64
#  1   Meat and fish            393 non-null    float64
#  2   Oils and fats            393 non-null    float64
#  3   Vegetables               393 non-null    float64
#  4   Pulses and products      393 non-null    float64
#  5   Sugar and Confectionery  393 non-null    float64
#  6   Housing                  393 non-null    float64
# dtypes: float64(7)
# memory usage: 21.6 KB

# %% [markdown]
# ## New Correlation 👇

# %%
cor = reduced_data.corr()
mask = np.triu(np.ones_like(cor, dtype=bool))
plt.figure(figsize=(12, 10))
sns.heatmap(cor, mask=mask,annot=True, cmap='coolwarm', fmt=".2f", annot_kws={"size": 8})
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# # Trend Analysis
# ## Overall CPI Trend Analysis of various features over the Years  👇

# %%
yearly_trends = numeric_columns.groupby(df['Year']).mean()

for category in reduced_data.columns:
    plt.plot(yearly_trends.index, yearly_trends[category], marker='o', linestyle='-', label=category)

plt.xlabel('Year')
plt.ylabel('CPI')
plt.title('Yearly Trends in CPI')
plt.legend(loc='upper right', bbox_to_anchor=(2, 1))
plt.grid(True)
plt.show()

# %% [markdown]
# ## CPI Trends for Rural and Urban Areas over the years 👇`

# %%
# filtering and calculating the mean for rural and urban sector
rural = reduced_data[df['Sector'] == 'Rural'].groupby(df['Year']).mean()
urban = reduced_data[df['Sector'] == 'Urban'].groupby(df['Year']).mean()

plt.figure(figsize=(15, 6))
plt.subplot(1, 2, 1)
for category in reduced_data.columns:
    plt.plot(rural.index, rural[category], marker='o', linestyle='-', label=category)

plt.xlabel('Year')
plt.ylabel('CPI')
plt.title('Yearly Trends in CPI for Rural Areas')
plt.legend(fontsize='x-small', loc='upper left', bbox_to_anchor=(1, 1))
plt.grid(True)


plt.subplot(1, 2, 2)
for category in reduced_data.columns:
    plt.plot(urban.index, urban[category], marker='o', linestyle='-', label=category)

plt.xlabel('Year')
plt.ylabel('CPI')
plt.title('Yearly Trends in CPI for Urban Areas')
plt.legend(fontsize='x-small', loc='upper left', bbox_to_anchor=(1, 1))
plt.grid(True)


plt.tight_layout()
plt.show()
